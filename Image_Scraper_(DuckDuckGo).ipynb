# %% [markdown]
# # DuckDuckGo Image Scraper
#
# This was originally an image scraper notebook for creating deep learning datasets.
#
# It has since been turned into an installable library and is much easier to use as you can simply drop a few lines of code into your own notebook as you're experimenting.
#
# This notebook now shows you how to use the library.
#
# Docs are at [joedockrill.github.io/jmd_imagescraper/](https://joedockrill.github.io/jmd_imagescraper/)
#
# Hugs & kisses, Joe Dockrill.

# %% [markdown]
# ## Install

# %%
# !pip install -q jmd_imagescraper
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.9 MB/s eta 0:00:00
#   Building wheel for bs4 (setup.py) ... done

# %% [markdown]
# ## Download images

# %%
from pathlib import Path
root = Path().cwd()/"images"

from jmd_imagescraper.core import * # dont't worry, it's designed to work with import *

duckduckgo_search(root, "Angry", "angry expression of human face", max_results=70)
duckduckgo_search(root, "Happy", "happy  expression of human face", max_results=70)
duckduckgo_search(root, "Sad", "sad  expression of human face", max_results=70)
duckduckgo_search(root, "Neutral", "neutral  expression of human face", max_results=70)

# file paths are returned so if you want to snag a list of downloaded files as you go, do this:

# images = []
# images.extend(duckduckgo_search(root, "Cats", "cute kittens", max_results=10))
# images.extend(duckduckgo_search(root, "Dogs", "cute puppies", max_results=10))
# images.extend(duckduckgo_search(root, "Birds", "cute baby ducks and chickens", max_results=10))
# images
# Out:
# Duckduckgo search: angry expression of human face
# Downloading results into /content/images/Angry
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='70' class='' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [70/70 00:12&lt;00:00 Images downloaded]
#     </div>
# Duckduckgo search: happy  expression of human face
# Downloading results into /content/images/Happy
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='70' class='' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [70/70 00:12&lt;00:00 Images downloaded]
#     </div>
# Duckduckgo search: sad  expression of human face
# Downloading results into /content/images/Sad
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='70' class='' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [70/70 00:12&lt;00:00 Images downloaded]
#     </div>
# Duckduckgo search: neutral  expression of human face
# Downloading results into /content/images/Neutral
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='70' class='' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [70/70 00:13&lt;00:00 Images downloaded]
#     </div>
# [PosixPath('/content/images/Neutral/071_b9cd70cb.jpg'),
#  PosixPath('/content/images/Neutral/072_f975911b.jpg'),
#  PosixPath('/content/images/Neutral/073_f9117d6c.jpg'),
#  PosixPath('/content/images/Neutral/074_c4176952.jpg'),
#  PosixPath('/content/images/Neutral/075_0e9366d3.jpg'),
#  PosixPath('/content/images/Neutral/076_2f4181d3.jpg'),
#  PosixPath('/content/images/Neutral/077_66849ddb.jpg'),
#  PosixPath('/content/images/Neutral/078_8ad9b38f.jpg'),
#  PosixPath('/content/images/Neutral/079_1de30716.jpg'),
#  PosixPath('/content/images/Neutral/080_e7c5867f.jpg'),
#  PosixPath('/content/images/Neutral/081_f3f3a8f1.jpg'),
#  PosixPath('/content/images/Neutral/082_d963b897.jpg'),
#  PosixPath('/content/images/Neutral/083_2c6f2eec.jpg'),
#  PosixPath('/content/images/Neutral/084_ccdb7177.jpg'),
#  PosixPath('/content/images/Neutral/085_d69f0ae9.jpg'),
#  PosixPath('/content/images/Neutral/086_57219f5c.jpg'),
#  PosixPath('/content/images/Neutral/087_ee149353.jpg'),
#  PosixPath('/content/images/Neutral/088_7c47f635.jpg'),
#  PosixPath('/content/images/Neutral/089_bc041ad8.jpg'),
#  PosixPath('/content/images/Neutral/090_d26864cf.jpg'),
#  PosixPath('/content/images/Neutral/091_9101654f.jpg'),
#  PosixPath('/content/images/Neutral/092_ca547033.jpg'),
#  PosixPath('/content/images/Neutral/093_8053dbed.jpg'),
#  PosixPath('/content/images/Neutral/094_7994d628.jpg'),
#  PosixPath('/content/images/Neutral/095_b3711876.jpg'),
#  PosixPath('/content/images/Neutral/096_103fd2ab.jpg'),
#  PosixPath('/content/images/Neutral/097_9d3c9dd7.jpg'),
#  PosixPath('/content/images/Neutral/098_3ef90924.jpg'),
#  PosixPath('/content/images/Neutral/099_76289cd0.jpg'),
#  PosixPath('/content/images/Neutral/100_ab163557.jpg'),
#  PosixPath('/content/images/Neutral/101_6bfcdd0b.jpg'),
#  PosixPath('/content/images/Neutral/102_3bb2d2f1.jpg'),
#  PosixPath('/content/images/Neutral/103_9e7d2f0a.jpg'),
#  PosixPath('/content/images/Neutral/104_b702dfea.jpg'),
#  PosixPath('/content/images/Neutral/105_84920399.jpg'),
#  PosixPath('/content/images/Neutral/106_7e4afed0.jpg'),
#  PosixPath('/content/images/Neutral/107_0c17c5a0.jpg'),
#  PosixPath('/content/images/Neutral/108_212ff632.jpg'),
#  PosixPath('/content/images/Neutral/109_28e08125.jpg'),
#  PosixPath('/content/images/Neutral/110_e02caaeb.jpg'),
#  PosixPath('/content/images/Neutral/111_3602816c.jpg'),
#  PosixPath('/content/images/Neutral/112_eed6a077.jpg'),
#  PosixPath('/content/images/Neutral/113_d69ccce2.jpg'),
#  PosixPath('/content/images/Neutral/114_da45094f.jpg'),
#  PosixPath('/content/images/Neutral/115_b545e4d6.jpg'),
#  PosixPath('/content/images/Neutral/116_aa02468e.jpg'),
#  PosixPath('/content/images/Neutral/117_548de098.jpg'),
#  PosixPath('/content/images/Neutral/118_60d1302f.jpg'),
#  PosixPath('/content/images/Neutral/119_67edd693.jpg'),
#  PosixPath('/content/images/Neutral/120_7b6365e4.jpg'),
#  PosixPath('/content/images/Neutral/121_0e1f5aa2.jpg'),
#  PosixPath('/content/images/Neutral/122_8c35ea33.jpg'),
#  PosixPath('/content/images/Neutral/123_24336098.jpg'),
#  PosixPath('/content/images/Neutral/124_6e5d8010.jpg'),
#  PosixPath('/content/images/Neutral/125_e7f8df12.jpg'),
#  PosixPath('/content/images/Neutral/126_2dba2c00.jpg'),
#  PosixPath('/content/images/Neutral/127_7aa09bcf.jpg'),
#  PosixPath('/content/images/Neutral/128_f9c3ff5b.jpg'),
#  PosixPath('/content/images/Neutral/129_eb81c1a8.jpg'),
#  PosixPath('/content/images/Neutral/130_0420f832.jpg'),
#  PosixPath('/content/images/Neutral/131_a078c68b.jpg'),
#  PosixPath('/content/images/Neutral/132_10a95d63.jpg'),
#  PosixPath('/content/images/Neutral/133_c2fefc83.jpg'),
#  PosixPath('/content/images/Neutral/134_a036993c.jpg'),
#  PosixPath('/content/images/Neutral/135_dfdb5a43.jpg'),
#  PosixPath('/content/images/Neutral/136_c613bf5f.jpg'),
#  PosixPath('/content/images/Neutral/137_d4ec491b.jpg'),
#  PosixPath('/content/images/Neutral/138_49029509.jpg'),
#  PosixPath('/content/images/Neutral/139_c632cd7f.jpg'),
#  PosixPath('/content/images/Neutral/140_02fa3556.jpg')]

# %% [markdown]
# ## Changing params across multiple searches

# %%
from pathlib import Path
root = Path().cwd()/"images"

from jmd_imagescraper.core import *

# If you're going to override default params across multiple searches you can use a
# dictionary like this (so you can change search params for the entire dataset once).

params = {
    "max_results": 80,             # this can go up to 477 at the time of writing
    "img_size":    ImgSize.Cached,
    "img_type":    ImgType.Photo,
    "img_layout":  ImgLayout.Square,
    #"img_color":   ImgColor.Purple
}

duckduckgo_search(root, "Angry", "angry expression of human face", **params)
duckduckgo_search(root, "Happy", "happy  expression of human face", **params)
duckduckgo_search(root, "Sad", "sad  expression of human face", **params)
duckduckgo_search(root, "Neutral", "neutral  expression of human face", **params)
# Out:
# Duckduckgo search: angry expression of human face
# Downloading results into /content/images/Angry
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='80' class='' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [80/80 00:13&lt;00:00 Images downloaded]
#     </div>
# Duckduckgo search: happy  expression of human face
# Downloading results into /content/images/Happy
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='80' class='' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [80/80 00:14&lt;00:00 Images downloaded]
#     </div>
# Duckduckgo search: sad  expression of human face
# Downloading results into /content/images/Sad
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='80' class='' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [80/80 00:14&lt;00:00 Images downloaded]
#     </div>
# Duckduckgo search: neutral  expression of human face
# Downloading results into /content/images/Neutral
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='80' class='' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [80/80 00:14&lt;00:00 Images downloaded]
#     </div>
# [PosixPath('/content/images/Neutral/001_e4e742ea.jpg'),
#  PosixPath('/content/images/Neutral/002_abb93047.jpg'),
#  PosixPath('/content/images/Neutral/003_e5105c63.jpg'),
#  PosixPath('/content/images/Neutral/004_87d80635.jpg'),
#  PosixPath('/content/images/Neutral/005_37a55323.jpg'),
#  PosixPath('/content/images/Neutral/006_9113b4b4.jpg'),
#  PosixPath('/content/images/Neutral/007_bd08ff72.jpg'),
#  PosixPath('/content/images/Neutral/008_42c760e8.jpg'),
#  PosixPath('/content/images/Neutral/009_d74a8f82.jpg'),
#  PosixPath('/content/images/Neutral/010_d73ef529.jpg'),
#  PosixPath('/content/images/Neutral/011_ee91d69f.jpg'),
#  PosixPath('/content/images/Neutral/012_284908ba.jpg'),
#  PosixPath('/content/images/Neutral/013_f667e152.jpg'),
#  PosixPath('/content/images/Neutral/014_6f94238c.jpg'),
#  PosixPath('/content/images/Neutral/015_ce4c4c33.jpg'),
#  PosixPath('/content/images/Neutral/016_413457f2.jpg'),
#  PosixPath('/content/images/Neutral/017_ffaf6427.jpg'),
#  PosixPath('/content/images/Neutral/018_f5a1d53a.jpg'),
#  PosixPath('/content/images/Neutral/019_fbb732cb.jpg'),
#  PosixPath('/content/images/Neutral/020_edc56eff.jpg'),
#  PosixPath('/content/images/Neutral/021_be45cb9c.jpg'),
#  PosixPath('/content/images/Neutral/022_d60ea18f.jpg'),
#  PosixPath('/content/images/Neutral/023_ac16a6c3.jpg'),
#  PosixPath('/content/images/Neutral/024_f9b8f898.jpg'),
#  PosixPath('/content/images/Neutral/025_df69c6b7.jpg'),
#  PosixPath('/content/images/Neutral/026_cde05349.jpg'),
#  PosixPath('/content/images/Neutral/027_fffe75ae.jpg'),
#  PosixPath('/content/images/Neutral/028_913e15d1.jpg'),
#  PosixPath('/content/images/Neutral/029_c563f6a4.jpg'),
#  PosixPath('/content/images/Neutral/030_8d548739.jpg'),
#  PosixPath('/content/images/Neutral/031_63ea677f.jpg'),
#  PosixPath('/content/images/Neutral/032_997b67a4.jpg'),
#  PosixPath('/content/images/Neutral/033_478299a2.jpg'),
#  PosixPath('/content/images/Neutral/034_a61e8eea.jpg'),
#  PosixPath('/content/images/Neutral/035_31e79b25.jpg'),
#  PosixPath('/content/images/Neutral/036_1de818fa.jpg'),
#  PosixPath('/content/images/Neutral/037_321ed7d4.jpg'),
#  PosixPath('/content/images/Neutral/038_1b525c2f.jpg'),
#  PosixPath('/content/images/Neutral/039_15d4d0f2.jpg'),
#  PosixPath('/content/images/Neutral/040_3fe02bfc.jpg'),
#  PosixPath('/content/images/Neutral/041_4d0ab563.jpg'),
#  PosixPath('/content/images/Neutral/042_1a4771a0.jpg'),
#  PosixPath('/content/images/Neutral/043_6aaf0308.jpg'),
#  PosixPath('/content/images/Neutral/044_89798610.jpg'),
#  PosixPath('/content/images/Neutral/045_6397b444.jpg'),
#  PosixPath('/content/images/Neutral/046_3f11bb97.jpg'),
#  PosixPath('/content/images/Neutral/047_6e56d292.jpg'),
#  PosixPath('/content/images/Neutral/048_3530a7e2.jpg'),
#  PosixPath('/content/images/Neutral/049_0296c05c.jpg'),
#  PosixPath('/content/images/Neutral/050_1828610f.jpg'),
#  PosixPath('/content/images/Neutral/051_74e4fd86.jpg'),
#  PosixPath('/content/images/Neutral/052_213227fd.jpg'),
#  PosixPath('/content/images/Neutral/053_5f41b158.jpg'),
#  PosixPath('/content/images/Neutral/054_0e83e48c.jpg'),
#  PosixPath('/content/images/Neutral/055_c6c3b210.jpg'),
#  PosixPath('/content/images/Neutral/056_165993bd.jpg'),
#  PosixPath('/content/images/Neutral/057_4302b370.jpg'),
#  PosixPath('/content/images/Neutral/058_eae1c0d4.jpg'),
#  PosixPath('/content/images/Neutral/059_3fcc55a0.jpg'),
#  PosixPath('/content/images/Neutral/060_e81ee85c.jpg'),
#  PosixPath('/content/images/Neutral/061_bcf31811.jpg'),
#  PosixPath('/content/images/Neutral/062_658862cb.jpg'),
#  PosixPath('/content/images/Neutral/063_a8d39bfa.jpg'),
#  PosixPath('/content/images/Neutral/064_7eca5fa6.jpg'),
#  PosixPath('/content/images/Neutral/065_d3e05ca9.jpg'),
#  PosixPath('/content/images/Neutral/066_494c3b72.jpg'),
#  PosixPath('/content/images/Neutral/067_5dcaad9d.jpg'),
#  PosixPath('/content/images/Neutral/068_21039374.jpg'),
#  PosixPath('/content/images/Neutral/069_1381e263.jpg'),
#  PosixPath('/content/images/Neutral/070_4069c04d.jpg'),
#  PosixPath('/content/images/Neutral/071_b29eb9bc.jpg'),
#  PosixPath('/content/images/Neutral/072_a059abad.jpg'),
#  PosixPath('/content/images/Neutral/073_7f408772.jpg'),
#  PosixPath('/content/images/Neutral/074_0c17e64a.jpg'),
#  PosixPath('/content/images/Neutral/075_335768a6.jpg'),
#  PosixPath('/content/images/Neutral/076_572b0bbe.jpg'),
#  PosixPath('/content/images/Neutral/077_4e13d2d3.jpg'),
#  PosixPath('/content/images/Neutral/078_d74e48cf.jpg'),
#  PosixPath('/content/images/Neutral/079_277ebe9b.jpg'),
#  PosixPath('/content/images/Neutral/080_cb9bfc56.jpg')]

# %% [markdown]
# ## Deleting all images

# %%
rmtree(root)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-dbf566c182bb> in <cell line: 1>()
# ----> 1 rmtree(root)
#
# /usr/local/lib/python3.10/dist-packages/jmd_imagescraper/core.py in rmtree(path)
#     147 def rmtree(path: Union[str, Path]):
#     148     '''Recursively delete a directory tree'''
# --> 149     path = Path(path); assert path.is_dir()
#     150     for p in reversed(list(path.glob('**/*'))):
#     151         if p.is_file():  p.unlink()
#
# AssertionError:

# %% [markdown]
# ## Displaying the image cleaner
#
# Use this to get rid of unsuitable images without leaving your notebook

# %%
from jmd_imagescraper.imagecleaner import *

display_image_cleaner(root)
# Out:
# HBox(children=(Button(description='|<<', layout=Layout(width='60px'), style=ButtonStyle()), Button(description…
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-f9ff279dcb0c> in <cell line: 3>()
#       1 from jmd_imagescraper.imagecleaner import *
#       2
# ----> 3 display_image_cleaner(root)
#
# /usr/local/lib/python3.10/dist-packages/jmd_imagescraper/imagecleaner.py in display_image_cleaner(path)
#     187     icln_create_widgets(ICLN_BATCH_SZ)
#     188     _,_,_,_,_,ddlFolder,_ = icln_pager.children
# --> 189     icln_render_batch(ddlFolder.value, 0)
#
# /usr/local/lib/python3.10/dist-packages/jmd_imagescraper/imagecleaner.py in icln_render_batch(folder, batch, force_reload)
#     162       btn.disabled = True
#     163     else:
# --> 164       img.value = open(fp, "rb").read()
#     165       btn.tag = (fp, img, batch, i)
#     166       btn.disabled = False
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/images/Angry/105_c346d560.jpg'

# %% [markdown]
# ## Create a zip to download or transfer to google drive

# %%
# create zip

ZIP_NAME = "images.zip" # maybe change this?

# !rm -f {ZIP_NAME}
# !zip -q -r {ZIP_NAME} {root}

# %%
# download to your local system

from google.colab import files
files.download(ZIP_NAME)

# %%
# copy to google drive

from google.colab import drive
import shutil

DESTINATION_FOLDER = "Datasets" # where would you like this in Google Drive?

drive.mount("/content/drive")
folder = Path("/content/drive/My Drive")/DESTINATION_FOLDER
folder.mkdir(parents=True, exist_ok=True)

shutil.copyfile(ZIP_NAME, str(folder/ZIP_NAME))

# %% [markdown]
# ## Create a CSV file of URLs
#
# If you'd rather distribute a file with the image URLs and labels and have people download the images themselves you can do so here.

# %%
CSV_NAME = "images.csv" # maybe change this?

# !rm -f {CSV_NAME}

csv = Path.cwd()/CSV_NAME
save_urls_to_csv(csv, "Nice", "nice clowns", max_results=5)
save_urls_to_csv(csv, "Scary", "scary clowns", max_results=5)
